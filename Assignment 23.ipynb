# %%
#1
import matplotlib.pyplot as plt
import numpy as np
import math
figure, axis = plt.subplots(2, 2)

# %%
plot1 = plt.subplot2grid((3, 3), (0, 0), colspan=2)
plot2 = plt.subplot2grid((3, 3), (0, 2), rowspan=3, colspan=2)
plot3 = plt.subplot2grid((3, 3), (1, 0), rowspan=2)

# %% [markdown]
# Thw other way to analyse is using pairplots.  It produces a matrix of relationships between each variable in your data for an instant examination of our data. It can also be a great jumping off point for determining types of regression analysis to use

# %% [markdown]
# 2. Compound interest makes a sum of money grow at a faster rate than simple interest, because in addition to earning returns on the money you invest, you also earn returns on those returns at the end of every compounding period, which could be daily, monthly, quarterly or annually

# %%
hist = [1,2,3,4,5,6,2,3,1,1,1]
import matplotlib.pyplot as plt
a = np.hstack((hist))
_ = plt.hist(a, bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
#Text(0.5, 1.0, "Histogram with 'auto' bins")
plt.show()

# %% [markdown]
# A histogram is a bar graph-like representation of data that buckets a range of outcomes into columns along the x-axis. The y-axis represents the number count or percentage of occurrences in the data for each column and can be used to visualize data distributions.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,math.pi,0.01)
y = np.sin(20*x)
# you can change the values of figsize to suitable aspect ratios
plt.figure(figsize = (10,4))
plt.plot(x,y)
plt.title('plot with undefined aspect ratio')
plt.show()

# %%
arr1 = np.random.randint(4,10,(3,3))
arr2 = np.random.randint(4,10,(3,3))

# %%
arr1 * arr2
#element wise multiplication
# Out:
# array([[16, 36, 28],
#        [40, 40, 63],
#        [54, 54, 48]])

# %%
#another way of doing the same element wise multiplication
C = np.multiply(arr1,arr2)
C
# Out:
# array([[16, 36, 28],
#        [40, 40, 63],
#        [54, 54, 48]])

# %%
#matrix multiplicaion
arr1@arr2
# Out:
# array([[127,  96, 114],
#        [165, 124, 148],
#        [150, 117, 135]])

# %%
#another way of scalar/dot product
C = np.dot(arr1,arr2)
C
# Out:
# array([[127,  96, 114],
#        [165, 124, 148],
#        [150, 117, 135]])

# %%
C = np.matmul(arr1,arr2)
C
# Out:
# array([[127,  96, 114],
#        [165, 124, 148],
#        [150, 117, 135]])

# %%
#6
price = 1000
np.divide(price,12)
# Out:
# 83.33333333333333

# %% [markdown]
# Or u could just plot using a bar graph so that u can visualize the data

# %%
arr1 = np.array([1,2,3,'abid'])
arr1
# Out:
# array(['1', '2', '3', 'abid'], dtype='<U11')

# %% [markdown]
# Yes, they can be stored but all the other elements inside also get coverted to string and may cause errors
