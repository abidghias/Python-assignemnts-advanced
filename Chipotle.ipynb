# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#converting the data type to numeric and removing the dollar symbol from the dataFrame
df['item_price'] = df['item_price'].str[1:].apply(pd.to_numeric)
#multiplying the two columns to get total price
df['total_price'] = df['item_price'] * df['quantity']
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
arr = df["choice_description"].to_numpy()

# %%
#getting all the possible choices
values = list()
for i in df["choice_description"]:
    values.append(i)
print(values)
# Out:
# [nan, '[Clementine]', '[Apple]', nan, '[Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]', '[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]', nan, '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]', '[Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]', '[Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]', nan, '[Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]', '[Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]', '[Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]', nan, nan, '[Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]', '[Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]', '[Sprite]', '[Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuc
# ...

# %%
filtered = df.drop_duplicates(['item_name','quantity'])
# select only the products with quantity equals to 1
one_prod = filtered[filtered.quantity == 1]
# select only the item_name and item_price columns
price_per_item = one_prod[['item_name', 'item_price']]
# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False).head()
# Out:
#                   item_name  item_price
# 606        Steak Salad Bowl       11.89
# 1229    Barbacoa Salad Bowl       11.89
# 1132    Carnitas Salad Bowl       11.89
# 7             Steak Burrito       11.75
# 168   Barbacoa Crispy Tacos       11.75

# %%
#Get all rows in a Pandas DataFrame containing given substring
df1 = df[df['item_name'].str.contains("Chicken Bowl")]
df1.head()
# Out:
#     order_id  quantity     item_name  \
# 4          2         2  Chicken Bowl
# 5          3         1  Chicken Bowl
# 13         7         1  Chicken Bowl
# 19        10         1  Chicken Bowl
# 26        13         1  Chicken Bowl
#
#                                    choice_description  item_price  total_price
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98        10.98
# 13  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25        11.25
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75         8.75
# 26  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49         8.49

# %%
#total amount spend on chicken bowl orders is 8044
df1.sum(axis = 0, skipna = True)
# Out:
# order_id                                                         713926
# quantity                                                            761
# item_name             Chicken BowlChicken BowlChicken BowlChicken Bo...
# choice_description    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# item_price                                                      7342.73
# total_price                                                     8044.63
# dtype: object
