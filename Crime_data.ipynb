# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
crime.Year = pd.to_datetime(crime.Year, format='%Y', errors='coerce')

crime = df.set_index('Year', drop = True)

# %%
crime.head()
crime.dtypes
# Out:
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %%
#selecting specific columns 

# we use loc option, before comma means row selection and after comma means coulumn selection
crime.loc[:, ['Burglary', 'Robbery']].head()
# Out:
#       Burglary  Robbery
# Year
# 1960    912100   107840
# 1961    949600   106670
# 1962    994300   110860
# 1963   1086400   116470
# 1964   1213200   130390

# %%
#we are selecting only the rows where the number of murder is greater than 24,000
df[df['Murder'] > 24000]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31  1991   252177000  14872900  1911770  12961100   24700         106590
# 33  1993   257908000  14144800  1926020  12218800   24530         106010
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 31   687730             1092740   3157200        8142200        1661700
# 33   659870             1135610   2834800        7820900        1563100

# %%
plt.plot(df['Total'], linestyle = 'dotted')
plt.xlabel('x - axis')
# Set the y axis label of the current axis.
plt.ylabel('y - axis')
plt.show()
#simple attempt to visualize the data

# %%
#Rate of the people commiting crimes... meaning from every x people, 1 person commits a crime
crime['Rate'] = df['Population']/df['Total']

# %%
df['Population']/df['Total']
# Out:
# 0     52.988350
# 1     52.463303
# 2     49.509888
# 3     45.865190
# 4     41.874644
# 5     40.833439
# 6     37.441562
# 7     33.448013
# 8     29.671587
# 9     27.174162
# 10    25.096974
# 11    24.011085
# 12    25.243672
# 13    24.070726
# 14    20.616771
# 15    18.873224
# 16    18.913187
# 17    19.694297
# 18    19.453921
# 19    17.967999
# 20    16.806699
# 21    17.070129
# 22    17.845450
# 23    19.323539
# 24    19.875608
# 25    19.204595
# 26    18.175543
# 27    17.935324
# 28    17.654617
# 29    17.418569
# 30    17.181317
# 31    16.955469
# 32    17.667161
# 33    18.233414
# 34    18.609743
# 35    18.954100
# 36    19.655496
# 37    20.283873
# 38    21.665913
# 39    23.438366
# 40    24.243639
# 41    24.023365
# 42    24.242364
# 43    24.579534
# 44    25.142985
# 45    25.637204
# 46    26.259544
# 47    26.806414
# 48    27.272405
# 49    28.524371
# 50    29.846971
# 51    30.372812
# 52    30.714539
# 53    32.130277
# 54    33.649562
# ...

# %% [markdown]
# But sir, i can't understand why it is not reflecting in the table, please guide me

# %%
crime.head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  Rate
# Year
# 1960              154320    912100        1855400         328200   NaN
# 1961              156760    949600        1913000         336000   NaN
# 1962              164570    994300        2089600         366800   NaN
# 1963              174210   1086400        2297800         408300   NaN
# 1964              203050   1213200        2514400         472800   NaN
